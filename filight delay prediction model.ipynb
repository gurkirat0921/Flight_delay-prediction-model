# %% [markdown]
# ## Import necessary libraries

# %%
import sys

# %%
# !conda install --yes --prefix {sys.prefix} catboost
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\gaguj\Desktop\bharat_intern\env
#
#   added / updated specs:
#     - catboost
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     boost-cpp-1.82.0           |       h59b6b97_2          11 KB
#     cairo-1.16.0               |       haedb8bc_5         1.9 MB
#     catboost-1.2               |  py310haa95532_0        53.0 MB
#     expat-2.5.0                |       hd77b12b_0         225 KB
#     font-ttf-dejavu-sans-mono-2.37|       hd3eb1b0_0         335 KB
#     font-ttf-inconsolata-2.001 |       hcb22688_0          83 KB
#     font-ttf-source-code-pro-2.030|       hd3eb1b0_0         654 KB
#     font-ttf-ubuntu-0.83       |       h8b1ccd4_0         1.5 MB
#     fontconfig-2.14.1          |       h9c4af85_2         198 KB
#     fonts-anaconda-1           |       h8fa9717_0           3 KB
#     fonts-conda-ecosystem-1    |       hd3eb1b0_0           5 KB
#     fribidi-1.0.10             |       h62dcd97_0          63 KB
#     getopt-win32-0.1           |       h2bbff1b_0          19 KB
#     graphite2-1.3.14           |       hd77b12b_1          91 KB
#     graphviz-2.50.0            |       h7eca76f_1        1007 KB
#     gts-0.7.6                  |       h63ab5a1_3         181 KB
#     harfbuzz-4.3.0             |       hb646838_1         855 KB
#     lcms2-2.12                 |       h83e58a3_0         454 KB
#     libboost-1.82.0            |       h3399ecb_2        23.1 MB
#     libgd-2.3.3                |       ha43c60c_1         314 KB
#     pango-1.50.7               |       h78c2152_0         279 KB
#     pixman-0.40.0              |       h2bbff1b_1         402 KB
#     plotly-5.9.0               |  py310haa95532_0         4.1 MB
#     poppler-22.12.0            |       h0bf3bde_3         2.5 MB
#     poppler-data-0.4.11        |       haa95532_1         432 KB
#     python-graphviz-0.20.1     |  py310haa95532_0          64 KB
#     tenacity-8.2.2             |  py310haa95532_0          38 KB
#     ------------------------------------------------------------
#                                            Total:        91.7 MB
#
# The following NEW packages will be INSTALLED:
#
#   boost-cpp          pkgs/main/win-64::boost-cpp-1.82.0-h59b6b97_2
#   cairo              pkgs/main/win-64::cairo-1.16.0-haedb8bc_5
#   catboost           pkgs/main/win-64::catboost-1.2-py310haa95532_0
#   expat              pkgs/main/win-64::expat-2.5.0-hd77b12b_0
#   font-ttf-dejavu-s~ pkgs/main/noarch::font-ttf-dejavu-sans-mono-2.37-hd3eb1b0_0
#   font-ttf-inconsol~ pkgs/main/noarch::font-ttf-inconsolata-2.001-hcb22688_0
#   font-ttf-source-c~ pkgs/main/noarch::font-ttf-source-code-pro-2.030-hd3eb1b0_0
#   font-ttf-ubuntu    pkgs/main/noarch::font-ttf-ubuntu-0.83-h8b1ccd4_0
#   fontconfig         pkgs/main/win-64::fontconfig-2.14.1-h9c4af85_2
#   fonts-anaconda     pkgs/main/noarch::fonts-anaconda-1-h8fa9717_0
#   fonts-conda-ecosy~ pkgs/main/noarch::fonts-conda-ecosystem-1-hd3eb1b0_0
#   fribidi            pkgs/main/win-64::fribidi-1.0.10-h62dcd97_0
#   getopt-win32       pkgs/main/win-64::getopt-win32-0.1-h2bbff1b_0
#   graphite2          pkgs/main/win-64::graphite2-1.3.14-hd77b12b_1
#   graphviz           pkgs/main/win-64::graphviz-2.50.0-h7eca76f_1
#   gts                pkgs/main/win-64::gts-0.7.6-h63ab5a1_3
#   harfbuzz           pkgs/main/win-64::harfbuzz-4.3.0-hb646838_1
#   lcms2              pkgs/main/win-64::lcms2-2.12-h83e58a3_0
#   libboost           pkgs/main/win-64::libboost-1.82.0-h3399ecb_2
#   libgd              pkgs/main/win-64::libgd-2.3.3-ha43c60c_1
#   pango              pkgs/main/win-64::pango-1.50.7-h78c2152_0
#   pixman             pkgs/main/win-64::pixman-0.40.0-h2bbff1b_1
#   plotly             pkgs/main/win-64::plotly-5.9.0-py310haa95532_0
#   poppler            pkgs/main/win-64::poppler-22.12.0-h0bf3bde_3
#   poppler-data       pkgs/main/win-64::poppler-data-0.4.11-haa95532_1
#   python-graphviz    pkgs/main/win-64::python-graphviz-0.20.1-py310haa95532_0
#   tenacity           pkgs/main/win-64::tenacity-8.2.2-py310haa95532_0
#
#
#
# Downloading and Extracting Packages
#
# python-graphviz-0.20 | 64 KB     |            |   0%
#
# boost-cpp-1.82.0     | 11 KB     |            |   0%
#
#
# font-ttf-dejavu-sans | 335 KB    |            |   0%
#
#
#
# getopt-win32-0.1     | 19 KB     |            |   0%
#
#
#
#
# graphviz-2.50.0      | 1007 KB   |            |   0%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    |            |   0%
#
#
#
#
#
#
# fontconfig-2.14.1    | 198 KB    |            |   0%
#
#
#
#
#
#
#
# fonts-conda-ecosyste | 5 KB      |            |   0%
#
#
#
#
#
#
#
#
# gts-0.7.6            | 181 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# expat-2.5.0          | 225 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# fonts-anaconda-1     | 3 KB      |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-inconsolata | 83 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# font-ttf-dejavu-sans | 335 KB    | 4          |   5%
#
#
#
#
# graphviz-2.50.0      | 1007 KB   | 1          |   2%
#
#
# font-ttf-dejavu-sans | 335 KB    | ########## | 100%
#
#
# font-ttf-dejavu-sans | 335 KB    | ########## | 100%
#
#
#
#
# graphviz-2.50.0      | 1007 KB   | ##3        |  24%
#
# boost-cpp-1.82.0     | 11 KB     | ########## | 100%
#
#
#
# getopt-win32-0.1     | 19 KB     | ########6  |  86%
#
# boost-cpp-1.82.0     | 11 KB     | ########## | 100%
#
#
#
#
#
#
# fontconfig-2.14.1    | 198 KB    | 8          |   8%
#
#
#
# getopt-win32-0.1     | 19 KB     | ########## | 100%
#
#
#
#
# graphviz-2.50.0      | 1007 KB   | #####5     |  56%
#
#
#
#
#
#
# fontconfig-2.14.1    | 198 KB    | ####8      |  49%
#
#
#
#
#
#
#
# fonts-conda-ecosyste | 5 KB      | ########## | 100%
#
#
#
#
#
#
#
# fonts-conda-ecosyste | 5 KB      | ########## | 100%
#
#
#
#
# graphviz-2.50.0      | 1007 KB   | ########4  |  84%
# python-graphviz-0.20 | 64 KB     | ##5        |  25%
#
#
#
#
#
#
#
#
# gts-0.7.6            | 181 KB    | 8          |   9%
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | 3          |   4%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# expat-2.5.0          | 225 KB    | 7          |   7%
#
#
#
#
#
#
#
#
# gts-0.7.6            | 181 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# gts-0.7.6            | 181 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# fonts-anaconda-1     | 3 KB      | ########## | 100%
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | 5          |   5%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | 1          |   2%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | 1          |   1%
#
#
#
#
#
#
# fontconfig-2.14.1    | 198 KB    | ########## | 100%
#
#
#
#
#
#
# fontconfig-2.14.1    | 198 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | ####7      |  48%
# python-graphviz-0.20 | 64 KB     | ########## | 100%
# python-graphviz-0.20 | 64 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##         |  21%
#
#
#
#
#
#
#
#
#
#
#
#
# fonts-anaconda-1     | 3 KB      | ########## | 100%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | 2          |   3%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
# expat-2.5.0          | 225 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | #######5   |  76%
#
#
#
#
#
#
#
#
#
#
#
# expat-2.5.0          | 225 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   |            |   0%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | 4          |   4%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | 3          |   3%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | 1          |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ###3       |  33%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgd-2.3.3          | 314 KB    | ########## | 100%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | 4          |   5%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | 2          |   3%
#
#
#
#
# graphviz-2.50.0      | 1007 KB   | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | 6          |   7%
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | #########5 |  95%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | 6          |   6%
#
#
#
#
#
#
#
#
#
# pixman-0.40.0        | 402 KB    | ########## | 100%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | 7          |   8%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | 3          |   3%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ####2      |  43%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | 1          |   2%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | 8          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #####1     |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | 4          |   5%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | #1         |  12%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | #8         |  18%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #####9     |  60%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | ##3        |  23%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #4         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | 5          |   6%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | ##7        |  27%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ##1        |  22%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ######8    |  68%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ##6        |  26%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | ###7       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | 7          |   8%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ##8        |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | #######3   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ##9        |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | 9          |   9%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########4  |  85%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | ####4      |  44%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ###1       |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #####4     |  54%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | 9          |  10%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ###5       |  35%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    |            |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ########## | 100%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | #####7     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | 7          |   7%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #1         |  12%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ###7       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #######8   |  79%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #          |  11%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #2         |  13%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | ########2  |  83%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ####6      |  47%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ########7  |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #5         |  15%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | #########9 |  99%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ##2        |  22%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | #########1 |  91%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ##6        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# harfbuzz-4.3.0       | 855 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | #####      |  51%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-inconsolata | 83 KB     | #9         |  19%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #6         |  16%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-inconsolata | 83 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-inconsolata | 83 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ###1       |  31%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #9         |  20%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | #####5     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ###6       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ##1        |  21%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ######3    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ######7    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ####9      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ##2        |  22%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | #######3   |  74%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #####8     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ##5        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ######4    |  65%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | #######7   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #######    |  70%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ##6        |  27%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ########   |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #######5   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ##8        |  28%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ########   |  81%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ###        |  31%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ########4  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ###3       |  34%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | #########4 |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #########2 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | #########7 |  97%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ###5       |  36%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | #########8 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ###7       |  37%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cairo-1.16.0         | 1.9 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ###8       |  38%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ###9       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ####1      |  41%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ####3      |  43%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ####4      |  45%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ####6      |  46%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ####7      |  48%
#
#
#
#
#
#
#
#
#
#
# poppler-22.12.0      | 2.5 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ####9      |  49%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #####      |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #####2     |  52%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #####3     |  54%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #####6     |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #####7     |  58%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ######     |  60%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ######1    |  62%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ######4    |  65%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ######6    |  67%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ######9    |  69%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #######    |  71%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #######2   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #######4   |  75%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #######8   |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ########   |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ########2  |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ########5  |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ########7  |  87%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ########9  |  90%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #########1 |  92%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #########4 |  94%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | #########7 |  98%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libboost-1.82.0      | 23.1 MB   | ########## | 100%
#
#
#
#
#
# plotly-5.9.0         | 4.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
# ==> WARNING: A newer version of conda exists. <==
#   current version: 23.5.2
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
# Or to minimize the number of packages updated during conda update use
#
#      conda install conda=23.9.0

# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

from sklearn.model_selection import train_test_split, GridSearchCV
from catboost import CatBoostClassifier, Pool
from sklearn.metrics import confusion_matrix
from sklearn import preprocessing
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.exceptions import DataConversionWarning

import warnings
warnings.filterwarnings(action='ignore', category=DataConversionWarning)
warnings.filterwarnings(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('flight_data.csv')

# %% [markdown]
# ### Data Format
# Instead of picking up dataset directly from Kaggle, I preferred to get the data from the website of [US Bureau of Transportation Statistics](https://www.transtats.bts.gov/DL_SelectFields.asp?Table_ID=236) for the month of February 2020.
# After carefully analyzing each data points, I decided to manually pick 9 variable to predict if there will be a delay in the flight.
# - __MONTH__ - Month
# - __DAY_OF_MONTH__ - Day of Month
# - __DAY_OF_WEEK__ - Day of Week
# - __OP_UNIQUE_CARRIER__ - Unique Carrier Code
# - __ORIGIN__ - Origin airport location
# - __DEST__ - Destination airport location
# - __DEP_TIME__ - Actual Departure Time (local time: hhmm)
# - __DEP_DEL15__ - Departure Delay Indicator, 15 Minutes or More (1=Yes, 0=No) [TARGET VARIABLE]
# - __DISTANCE__ - Distance between airports (miles)

# %%
data.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK OP_UNIQUE_CARRIER ORIGIN DEST  DEP_TIME  \
# 0      2             1            6                MQ    CLT  LYH    1430.0
# 1      2             8            6                MQ    CLT  LYH    1442.0
# 2      2            13            4                MQ    DFW  SHV    2247.0
# 3      2            14            5                MQ    DFW  SHV    2230.0
# 4      2            15            6                MQ    DFW  SHV    2246.0
#
#    DEP_DEL15  DISTANCE  Unnamed: 9
# 0        0.0     175.0         NaN
# 1        0.0     175.0         NaN
# 2        0.0     190.0         NaN
# 3        0.0     190.0         NaN
# 4        0.0     190.0         NaN

# %% [markdown]
# ## Data Preprocessing

# %%
data = data.drop(['Unnamed: 9'], axis=1)

# %%
data['DEP_DEL15'].value_counts()
# Out:
# DEP_DEL15
# 0.0    487135
# 1.0     82182
# Name: count, dtype: int64

# %%
# Split the data into positive and negative
positive_rows = data.DEP_DEL15 == 1.0
data_pos = data.loc[positive_rows]
data_neg = data.loc[~positive_rows]

# Merge the balanced data
data = pd.concat([data_pos, data_neg.sample(n = len(data_pos))], axis = 0)

# Shuffle the order of data
data = data.sample(n = len(data)).reset_index(drop = True)

# %%
data.isna().sum()
# Out:
# MONTH                  0
# DAY_OF_MONTH           0
# DAY_OF_WEEK            0
# OP_UNIQUE_CARRIER      0
# ORIGIN                 0
# DEST                   0
# DEP_TIME             793
# DEP_DEL15            793
# DISTANCE               0
# dtype: int64

# %%
data = data.dropna(axis=0)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 163571 entries, 1 to 164363
# Data columns (total 9 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   MONTH              163571 non-null  int64
#  1   DAY_OF_MONTH       163571 non-null  int64
#  2   DAY_OF_WEEK        163571 non-null  int64
#  3   OP_UNIQUE_CARRIER  163571 non-null  object
#  4   ORIGIN             163571 non-null  object
#  5   DEST               163571 non-null  object
#  6   DEP_TIME           163571 non-null  float64
#  7   DEP_DEL15          163571 non-null  float64
#  8   DISTANCE           163571 non-null  float64
# dtypes: float64(3), int64(3), object(3)
# memory usage: 12.5+ MB

# %%
data['DEP_DEL15'] = data['DEP_DEL15'].astype(int)

# %%
data.shape
# Out:
# (163571, 9)

# %% [markdown]
# ## Exploratory Data Analysis

# %%
data.describe()
# Out:
#           MONTH   DAY_OF_MONTH    DAY_OF_WEEK       DEP_TIME      DEP_DEL15  \
# count  163571.0  163571.000000  163571.000000  163571.000000  163571.000000
# mean        2.0      14.799989       4.017668    1417.090022       0.502424
# std         0.0       8.184351       1.920453     497.838869       0.499996
# min         2.0       1.000000       1.000000       1.000000       0.000000
# 25%         2.0       7.000000       2.000000    1027.000000       0.000000
# 50%         2.0      14.000000       4.000000    1438.000000       1.000000
# 75%         2.0      22.000000       6.000000    1826.000000       1.000000
# max         2.0      29.000000       7.000000    2400.000000       1.000000
#
#             DISTANCE
# count  163571.000000
# mean      792.215277
# std       574.255506
# min        31.000000
# 25%       370.000000
# 50%       643.000000
# 75%      1034.000000
# max      5095.000000

# %%
plt.figure(figsize=(15,5))
sns.distplot(data['DISTANCE'],hist= False, color="b", kde_kws={"shade": True})
plt.xlabel("Distance")
plt.ylabel("Frequency")
plt.title("Distribution of distance")
plt.show();

# %%
print(f"Average distance if there is a delay {data[data['DEP_DEL15'] == 1]['DISTANCE'].values.mean()} miles")
print(f"Average distance if there is no delay {data[data['DEP_DEL15'] == 0]['DISTANCE'].values.mean()} miles")
# Out:
# Average distance if there is a delay 786.1071280815751 miles
# Average distance if there is no delay 798.3829387263635 miles

# %% [markdown]
# ### Count of carriers in the dataset

# %%
plt.figure(figsize=(15,5))
sns.countplot(x=data['OP_UNIQUE_CARRIER'], data=data)
plt.xlabel("Carriers")
plt.ylabel("Count")
plt.title("Count of unique carrier")
plt.show()

# %% [markdown]
# ### Count of origin and destination airport

# %%
plt.figure(figsize=(10,70))
sns.countplot(y=data['ORIGIN'], data=data, orient="h")
plt.xlabel("Airport")
plt.ylabel("Count")
plt.title("Count of Unique Origin Airports")
plt.show()

# %%
plt.figure(figsize=(10,70))
sns.countplot(y=data['DEST'], data=data, orient="h")
plt.xlabel("Airport")
plt.ylabel("Count")
plt.title("Count of Unique Destination Airports")
plt.show()

# %% [markdown]
# ## Modelling

# %%
data = data.rename(columns={'DEP_DEL15':'TARGET'})

# %% [markdown]
# __Encoding the categorical variable__

# %%
def label_encoding(categories):
    #To perform mapping of categorical features
    categories = list(set(list(categories.values)))
    mapping = {}
    for idx in range(len(categories)):
        mapping[categories[idx]] = idx
    return mapping

# %%
data['OP_UNIQUE_CARRIER'] = data['OP_UNIQUE_CARRIER'].map(label_encoding(data['OP_UNIQUE_CARRIER']))

# %%
data['ORIGIN'] = data['ORIGIN'].map(label_encoding(data['ORIGIN']))

# %%
data['DEST'] = data['DEST'].map(label_encoding(data['DEST']))

# %%
data.head()
# Out:
#    MONTH  DAY_OF_MONTH  DAY_OF_WEEK  OP_UNIQUE_CARRIER  ORIGIN  DEST  \
# 1      2            23            7                 14     218   272
# 2      2            23            7                  3     149   216
# 3      2            26            3                 12     272   149
# 4      2            17            1                 10     272    50
# 5      2             2            7                  3      36   214
#
#    DEP_TIME  TARGET  DISTANCE
# 1     552.0       0     475.0
# 2    1214.0       1     472.0
# 3    2117.0       1     621.0
# 4    1413.0       0     612.0
# 5    1507.0       1     353.0

# %%
data['TARGET'].value_counts()
# Out:
# TARGET
# 1    82182
# 0    81389
# Name: count, dtype: int64

# %%
X = data.drop(['MONTH','TARGET'], axis=1)
y = data[['TARGET']].values

# %%
# Splitting Train-set and Test-set
X_train, X_test, y_train, y_test= train_test_split(X, y, test_size=0.2, random_state=41)

# Splitting Train-set and Validation-set
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.25, random_state=41)

# %% [markdown]
# ### Choosing the evaluation metric

# %%
# Formula to get accuracy
def get_accuracy(y_true, y_preds):
    # Getting score of confusion matrix
    true_negative, false_positive, false_negative, true_positive = confusion_matrix(y_true, y_preds).ravel()
    # Calculating accuracy
    accuracy = (true_positive + true_negative)/(true_negative + false_positive + false_negative + true_positive)
    return accuracy

# %% [markdown]
# ### Creating some baseline models

# %% [markdown]
# __Logistic Regression__

# %%
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression(random_state=0,max_iter=200).fit(X_train, y_train)

# %% [markdown]
# __CatboostClassifier__

# %%
# Initialize CatBoostClassifier
catboost = CatBoostClassifier(random_state=0)
catboost.fit(X_train, y_train, verbose=False)

# %% [markdown]
# __Naive Bayes__

# %%
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %% [markdown]
# __Random Forest Classifier__

# %%
rf = RandomForestClassifier(random_state=0)
rf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=0)

# %% [markdown]
# __KNN Classifier__

# %%
knn = KNeighborsClassifier(n_neighbors=2)
knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=2)

# %% [markdown]
# ### Evaluation of accuracy on validation dataset

# %%
models = [lr, catboost, gnb, rf, knn]
acc = []
for model in models:
    preds_val = model.predict(X_val)
    accuracy = get_accuracy(y_val, preds_val)
    acc.append(accuracy)

# %%
model_name = ['Logistic Regression', 'Catboost', 'Naive Bayes', 'Random Forest', 'KNN']
accuracy = dict(zip(model_name, acc))

# %%
plt.figure(figsize=(15,5))
ax = sns.barplot(x = list(accuracy.keys()), y = list(accuracy.values()))
for p, value in zip(ax.patches, list(accuracy.values())):
    _x = p.get_x() + p.get_width() / 2
    _y = p.get_y() + p.get_height() + 0.008
    ax.text(_x, _y, round(value, 3), ha="center") 
plt.xlabel("Models")
plt.ylabel("Accuracy")
plt.title("Model vs. Accuracy")
plt.show()

# %% [markdown]
# # THANKYOU
